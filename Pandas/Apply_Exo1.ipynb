# %% [markdown]
# # <span style = "color:green"> PANDAS HWK4 </span>
#
# ### Apply and Applymap : Student Alcohol Consumption

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("student-mat.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df1 = df.loc[:,"school": "guardian"] # only way to do it, you have to use loc or iloc
df1.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### 3. Create a lambda function that capitalizes strings

# %%
def capString(x):
    if(type(x)==str):
        return x.upper()
    else:
        return x
#df1.loc[:,:].applymap(lambda x: capString(x)) 

# apply works on a row / column basis of a DataFrame, applymap works element-wise on a DataFrame, 
# and map works element-wise on a Series.
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   AT_HOME   TEACHER
# 1       GP   F   17       U     GT3       T     1     1   AT_HOME     OTHER
# 2       GP   F   15       U     LE3       T     1     1   AT_HOME     OTHER
# 3       GP   F   15       U     GT3       T     4     2    HEALTH  SERVICES
# 4       GP   F   16       U     GT3       T     3     3     OTHER     OTHER
# 5       GP   M   16       U     LE3       T     4     3  SERVICES     OTHER
# 6       GP   M   16       U     LE3       T     2     2     OTHER     OTHER
# 7       GP   F   17       U     GT3       A     4     4     OTHER   TEACHER
# 8       GP   M   15       U     LE3       A     3     2  SERVICES     OTHER
# 9       GP   M   15       U     GT3       T     3     4     OTHER     OTHER
# 10      GP   F   15       U     GT3       T     4     4   TEACHER    HEALTH
# ...

# %% [markdown]
# ### 4. Capitalize both Mjob and Fjob
#
# applymap() a data frame function, returns  a data frame. Apply a function to a DataFrame that is intended to operate
# elementwise, i.e. like doing map(func, series) for each series in the
# DataFrame

# %%
df1[['Mjob','Fjob']].applymap(lambda x: capString(x)).head()
# Out:
#       Mjob      Fjob
# 0  AT_HOME   TEACHER
# 1  AT_HOME     OTHER
# 2  AT_HOME     OTHER
# 3   HEALTH  SERVICES
# 4    OTHER     OTHER

# %% [markdown]
# ### 5. Print the last elements of the dataset

# %%
df1.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 390  course    other
# 391  course   mother
# 392  course    other
# 393  course   mother
# 394  course   father

# %% [markdown]
# ### 6. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob

# %%
# because apply functions only act on a copy of the dataset not the real dataset.
df1[['Mjob','Fjob']] = df1[['Mjob','Fjob']].applymap(lambda x: capString(x))

# %%
df1.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  AT_HOME   TEACHER
# 1     GP   F   17       U     GT3       T     1     1  AT_HOME     OTHER
# 2     GP   F   15       U     LE3       T     1     1  AT_HOME     OTHER
# 3     GP   F   15       U     GT3       T     4     2   HEALTH  SERVICES
# 4     GP   F   16       U     GT3       T     3     3    OTHER     OTHER
#
#    reason guardian  legal_drinker
# 0  course   mother          False
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False

# %% [markdown]
# ### 7. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(x):
    if(x>20):
        return True
    else:
        return False
df1['legal_drinker'] = df1.age.apply(lambda x: majority(x))

# %%
df1.tail(3)
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 392     MS   M   21       R     GT3       T     1     1     other    other
# 393     MS   M   18       R     LE3       T     3     2  services    other
# 394     MS   M   19       U     LE3       T     1     1     other  at_home
#
#      reason guardian  legal_drinker
# 392  course    other           True
# 393  course   mother          False
# 394  course   father          False

# %% [markdown]
# ### 8. Multiply every number of the dataset by 10

# %%
df1[["age","Medu","Fedu"]] = df1[["age","Medu","Fedu"]].applymap(lambda x: 10*x)
df1.head()
# Out:
#   school sex   age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F  1620       U     GT3       A   360   360  AT_HOME   TEACHER
# 1     GP   F  1530       U     GT3       T    90    90  AT_HOME     OTHER
# 2     GP   F  1350       U     LE3       T    90    90  AT_HOME     OTHER
# 3     GP   F  1350       U     GT3       T   360   180   HEALTH  SERVICES
# 4     GP   F  1440       U     GT3       T   270   270    OTHER     OTHER
#
#    reason guardian  legal_drinker
# 0  course   mother          False
# 1  course   father          False
# 2   other   mother          False
# 3    home   mother          False
# 4    home   father          False
