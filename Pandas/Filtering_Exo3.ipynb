# %% [markdown]
# # <span style = "color:brown"> PANDAS HWK2 </span>
#
# ### Filtering : Fictional Army

# %%
import numpy as np
import pandas as pd

# %%
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %% [markdown]
# ### Create a dataframe of the raw_data

# %%
army = pd.DataFrame(raw_data)

# %%
army.head()
# Out:
#    armored  battles company  deaths  deserters      origin  readiness  \
# 0        1        5     1st     523          4     Arizona          1
# 1        0       42     1st      52         24  California          2
# 2        1        2     2nd      25         31       Texas          3
# 3        1        2     2nd     616          2     Florida          3
# 4        0        4     1st      43          3       Maine          2
#
#      regiment  size  veterans
# 0  Nighthawks  1045         1
# 1  Nighthawks   957         5
# 2  Nighthawks  1099        62
# 3  Nighthawks  1400        26
# 4    Dragoons  1592        73

# %% [markdown]
# ### Set the 'origin' as the index of the dataframe

# %%
army.set_index("origin",inplace = True)

# %%
army.head()
# Out:
#             armored  battles company  deaths  deserters  readiness  \
# origin
# Arizona           1        5     1st     523          4          1
# California        0       42     1st      52         24          2
# Texas             1        2     2nd      25         31          3
# Florida           1        2     2nd     616          2          3
# Maine             0        4     1st      43          3          2
#
#               regiment  size  veterans
# origin
# Arizona     Nighthawks  1045         1
# California  Nighthawks   957         5
# Texas       Nighthawks  1099        62
# Florida     Nighthawks  1400        26
# Maine         Dragoons  1592        73

# %% [markdown]
# ### Print the column veteran

# %%
army['veterans']
# Out:
# origin
# Arizona         1
# California      5
# Texas          62
# Florida        26
# Maine          73
# Iowa           37
# Alaska        949
# Washington     48
# Oregon         48
# Wyoming       435
# Louisana       63
# Georgia       345
# Name: veterans, dtype: int64

# %% [markdown]
# ### Print the veterans and deaths

# %%
army[['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %% [markdown]
# ### Print the names of the columns

# %%
army.columns
# Out:
# Index(['armored', 'battles', 'company', 'deaths', 'deserters', 'readiness',
#        'regiment', 'size', 'veterans'],
#       dtype='object')

# %% [markdown]
# ### Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
army.loc[['Maine','Alaska'],['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %% [markdown]
# ### Select the rows 3 to 7 and the columns 3 to 6

# %%
army.head(2)
# Out:
#             armored  battles company  deaths  deserters  readiness  \
# origin
# Arizona           1        5     1st     523          4          1
# California        0       42     1st      52         24          2
#
#               regiment  size  veterans
# origin
# Arizona     Nighthawks  1045         1
# California  Nighthawks   957         5

# %%
army.iloc[3:8,3:7]
# Out:
#             deaths  deserters  readiness    regiment
# origin
# Florida        616          2          3  Nighthawks
# Maine           43          3          2    Dragoons
# Iowa           234          4          1    Dragoons
# Alaska         523         24          2    Dragoons
# Washington      62         31          3    Dragoons

# %% [markdown]
# ### Select every other row after the fourth row

# %%
army.iloc[3:]
# Out:
#             armored  battles company  deaths  deserters  readiness  \
# origin
# Florida           1        2     2nd     616          2          3
# Maine             0        4     1st      43          3          2
# Iowa              1        7     1st     234          4          1
# Alaska            0        8     2nd     523         24          2
# Washington        1        3     2nd      62         31          3
# Oregon            0        4     1st      62          2          2
# Wyoming           0        7     1st      73          3          1
# Louisana          1        8     2nd      37          2          2
# Georgia           1        9     2nd      35          3          3
#
#               regiment  size  veterans
# origin
# Florida     Nighthawks  1400        26
# Maine         Dragoons  1592        73
# Iowa          Dragoons  1006        37
# Alaska        Dragoons   987       949
# Washington    Dragoons   849        48
# Oregon          Scouts   973        48
# Wyoming         Scouts  1005       435
# Louisana        Scouts  1099        63
# Georgia         Scouts  1523       345

# %% [markdown]
# ### Select every row up to the 4th row

# %%
army.iloc[:4]
# Out:
#             armored  battles company  deaths  deserters  readiness  \
# origin
# Arizona           1        5     1st     523          4          1
# California        0       42     1st      52         24          2
# Texas             1        2     2nd      25         31          3
# Florida           1        2     2nd     616          2          3
#
#               regiment  size  veterans
# origin
# Arizona     Nighthawks  1045         1
# California  Nighthawks   957         5
# Texas       Nighthawks  1099        62
# Florida     Nighthawks  1400        26

# %% [markdown]
# ###  Select the 3rd column up to the 7th column

# %%
army.iloc[:,3:8]
# Out:
#             deaths  deserters  readiness    regiment  size
# origin
# Arizona        523          4          1  Nighthawks  1045
# California      52         24          2  Nighthawks   957
# Texas           25         31          3  Nighthawks  1099
# Florida        616          2          3  Nighthawks  1400
# Maine           43          3          2    Dragoons  1592
# Iowa           234          4          1    Dragoons  1006
# Alaska         523         24          2    Dragoons   987
# Washington      62         31          3    Dragoons   849
# Oregon          62          2          2      Scouts   973
# Wyoming         73          3          1      Scouts  1005
# Louisana        37          2          2      Scouts  1099
# Georgia         35          3          3      Scouts  1523

# %% [markdown]
# ### Select rows where df.deaths is greater than 50

# %%
army[army.deaths > 50]
# Out:
#             armored  battles company  deaths  deserters  readiness  \
# origin
# Arizona           1        5     1st     523          4          1
# California        0       42     1st      52         24          2
# Florida           1        2     2nd     616          2          3
# Iowa              1        7     1st     234          4          1
# Alaska            0        8     2nd     523         24          2
# Washington        1        3     2nd      62         31          3
# Oregon            0        4     1st      62          2          2
# Wyoming           0        7     1st      73          3          1
#
#               regiment  size  veterans
# origin
# Arizona     Nighthawks  1045         1
# California  Nighthawks   957         5
# Florida     Nighthawks  1400        26
# Iowa          Dragoons  1006        37
# Alaska        Dragoons   987       949
# Washington    Dragoons   849        48
# Oregon          Scouts   973        48
# Wyoming         Scouts  1005       435

# %% [markdown]
# ### Select rows where df.deaths is greater than 500 or less than 50

# %%
army[(army.deaths < 50) | (army.deaths > 500)]
# Out:
#           armored  battles company  deaths  deserters  readiness    regiment  \
# origin
# Arizona         1        5     1st     523          4          1  Nighthawks
# Texas           1        2     2nd      25         31          3  Nighthawks
# Florida         1        2     2nd     616          2          3  Nighthawks
# Maine           0        4     1st      43          3          2    Dragoons
# Alaska          0        8     2nd     523         24          2    Dragoons
# Louisana        1        8     2nd      37          2          2      Scouts
# Georgia         1        9     2nd      35          3          3      Scouts
#
#           size  veterans
# origin
# Arizona   1045         1
# Texas     1099        62
# Florida   1400        26
# Maine     1592        73
# Alaska     987       949
# Louisana  1099        63
# Georgia   1523       345

# %% [markdown]
# ### Select all the regiments not named "Dragoons"

# %%
army[army.regiment != "Dragoons"]
# Out:
#             armored  battles company  deaths  deserters  readiness  \
# origin
# Arizona           1        5     1st     523          4          1
# California        0       42     1st      52         24          2
# Texas             1        2     2nd      25         31          3
# Florida           1        2     2nd     616          2          3
# Oregon            0        4     1st      62          2          2
# Wyoming           0        7     1st      73          3          1
# Louisana          1        8     2nd      37          2          2
# Georgia           1        9     2nd      35          3          3
#
#               regiment  size  veterans
# origin
# Arizona     Nighthawks  1045         1
# California  Nighthawks   957         5
# Texas       Nighthawks  1099        62
# Florida     Nighthawks  1400        26
# Oregon          Scouts   973        48
# Wyoming         Scouts  1005       435
# Louisana        Scouts  1099        63
# Georgia         Scouts  1523       345

# %% [markdown]
# ### Select the rows called Texas and Arizona

# %%
army.loc[['Texas','Arizona']]
# Out:
#          armored  battles company  deaths  deserters  readiness    regiment  \
# origin
# Texas          1        2     2nd      25         31          3  Nighthawks
# Arizona        1        5     1st     523          4          1  Nighthawks
#
#          size  veterans
# origin
# Texas    1099        62
# Arizona  1045         1

# %% [markdown]
# ### Select the third cell in the row named Arizona

# %%
army.loc['Arizona','company']
# Out:
# '1st'

# %%
army.iloc[0,2]
# Out:
# '1st'

# %% [markdown]
# ### Select the third cell down in the column named deaths

# %%
army.loc['Texas','deaths']
# Out:
# 25

# %%
army.iloc[2,3]
# Out:
# 25
