# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %%
apple = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv")

# %%
display(apple)
# Out:
#             Date    Open    High     Low   Close     Volume  Adj Close
# 0     2014-07-08   96.27   96.80   93.92   95.35   65130000      95.35
# 1     2014-07-07   94.14   95.99   94.10   95.97   56305400      95.97
# 2     2014-07-03   93.67   94.10   93.20   94.03   22891800      94.03
# 3     2014-07-02   93.87   94.06   93.09   93.48   28420900      93.48
# 4     2014-07-01   93.52   94.07   93.13   93.52   38170200      93.52
# 5     2014-06-30   92.10   93.73   92.09   92.93   49482300      92.93
# 6     2014-06-27   90.82   92.00   90.77   91.98   64006800      91.98
# 7     2014-06-26   90.37   91.05   89.80   90.90   32595800      90.90
# 8     2014-06-25   90.21   90.70   89.65   90.36   36852200      90.36
# 9     2014-06-24   90.75   91.74   90.19   90.28   38988300      90.28
# 10    2014-06-23   91.32   91.62   90.60   90.83   43618200      90.83
# 11    2014-06-20   91.85   92.55   90.90   90.91  100813200      90.91
# ...

# %% [markdown]
# ### Check out the columns types

# %%
apple.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume         int64
# Adj Close    float64
# dtype: object

# %% [markdown]
# ### Transform the date type as a datetime

# %%
apple['Date'] = pd.to_datetime(apple.Date)

# %%
apple.Date.dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ### Set the date column as index

# %%
apple.set_index('Date',inplace = True)

# %%
apple.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# ### Is there any duplicate dates

# %%
# detect duplicate dates (the index)
apple.index.duplicated().sum() # there are no duplicate dates
# Out:
# 0

# %% [markdown]
# ### Oops the index wast in ascending order. Now make the oldest date the first entry in the index column

# %%
# SOLUTION: apple.sort_index(ascending = True, inplace = True) will work because 2014 is greater than 1980

# %%
apple.head()
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
apple.reset_index(drop = False, inplace = True)

# %%
apple.head()
# Out:
#         Date   Open   High    Low  Close    Volume  Adj Close
# 0 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2 2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3 2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4 2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %%
apple.sort_index(ascending = False, inplace = True)

# %%
apple.head()
# Out:
#            Date   Open   High    Low  Close     Volume  Adj Close
# 8464 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 8463 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8462 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8461 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8460 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %%
apple.set_index('Date', inplace = True)

# %%
apple.head()
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %% [markdown]
# ### Get the last business day of each month

# %%
#SOLUTION: apple_month = apple.resample('BM').mean(), resample group time data by the frequency entered, here 
# BM: business end month

# apple_month.head()

# %%
apple.reset_index(drop = False, inplace = True)

# %%
apple[apple.Date.dt.is_month_end].head()
# Out:
#           Date   Open   High    Low  Close   Volume  Adj Close
# 12  1980-12-31  34.25  34.25  34.13  34.13  8937600       0.53
# 74  1981-03-31  24.75  24.75  24.50  24.50  3998400       0.38
# 95  1981-04-30  28.38  28.62  28.38  28.38  3152800       0.44
# 137 1981-06-30  26.13  26.13  26.00  26.00  8976800       0.41
# 159 1981-07-31  25.00  25.12  25.00  25.00  2738400       0.39

# %% [markdown]
# ### Get the difference of days between the oldest date and the first date

# %%
#BETTER WAY: (apple.index.max() - apple.index.min())

# %%
apple.Date[8464] - apple.Date[0]
# Out:
# Timedelta('12261 days 00:00:00')

# %% [markdown]
# ### How many months do we have in the data?

# %%
# OTHER WAY:

# %%
# Period extracts all months in the dataset, included duplicate.
pd.PeriodIndex(apple.Date, freq = "M").nunique()
# Out:
# 404

# %% [markdown]
# ### Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inches

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
apple.head()
# Out:
#         Date   Open   High    Low  Close     Volume  Adj Close
# 0 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 1 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 2 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 3 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 4 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41

# %%
plt.figure(figsize = (13.5,9))
plt.plot(apple['Date'],apple['Adj Close'], c = "purple")
plt.xlabel("Dates")
plt.ylabel("Adj Close")
plt.title("Apple Stock")
